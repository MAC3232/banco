# %%
import pandas as pd
import numpy as np
df=pd.read_csv('/content/drive/MyDrive/nuevo/csv/GTAV_Steam_Reviews (1).csv')
df
# Out:
#               id language                                             review  \
# 0      157337410  english  Games good, But Rockstar Your a BILLION DOLLAR...
# 1      157337371  english         modders make it better and free everything
# 2      157337210  english                                         great game
# 3      157336468  english                                               best
# 4      157335380  english                                                sed
# ...          ...      ...                                                ...
# 52094  140767442  english                                         great game
# 52095  140766922  english  This game destroys lives and breaks families. ...
# 52096  140766772  english  this is such a fun you need to try it out the ...
# 52097  140766435  english                                                 gg
# 52098  140766317  english  De los mejores juegos del mundo... Mas que nad...
#
# ...

# %% [markdown]
# **Inspeccion de Datos **

# %%
df.dtypes
# Out:
# id                                 int64
# language                          object
# review                            object
# created                           object
# voted_up                            bool
# votes_up                           int64
# comment_count                      int64
# steam_purchase                      bool
# recieved_for_free                   bool
# written_during_early_access         bool
# author_num_games_owned             int64
# author_num_reviews                 int64
# author_playtime_forever            int64
# author_playtime_last_two_weeks     int64
# author_playtime_at_review          int64
# author_last_played                object
# dtype: object

# %%
df.describe()
# Out:
#                  id      votes_up  comment_count  author_num_games_owned  \
# count  5.209900e+04  52099.000000   52099.000000            52099.000000
# mean   1.489459e+08      0.584387       0.018522               20.017467
# std    5.183634e+06     22.359856       0.352163              127.495124
# min    1.407663e+08      0.000000       0.000000                0.000000
# 25%    1.440101e+08      0.000000       0.000000                0.000000
# 50%    1.486648e+08      0.000000       0.000000                0.000000
# 75%    1.539681e+08      0.000000       0.000000                6.000000
# max    1.573374e+08   3942.000000      46.000000            18126.000000
#
#        author_num_reviews  author_playtime_forever  \
# count        52099.000000             5.209900e+04
# mean             5.844738             1.118878e+04
# std             12.600061             2.473005e+04
# min              1.000000             5.000000e+00
# ...

# %%
df.head(8000)
# Out:
#              id language                                             review  \
# 0     157337410  english  Games good, But Rockstar Your a BILLION DOLLAR...
# 1     157337371  english         modders make it better and free everything
# 2     157337210  english                                         great game
# 3     157336468  english                                               best
# 4     157335380  english                                                sed
# ...         ...      ...                                                ...
# 7995  155000238  english                                            i cheat
# 7996  154999859  english                                              GTA 5
# 7997  154999721  english                                  ddwdawdwdawwaadad
# 7998  154999440  english  dis game is vey family friendly and will teach...
# 7999  154998823  english                                          Fun game!
#
# ...

# %%
df.tail()
# Out:
#               id language                                             review  \
# 52094  140767442  english                                         great game
# 52095  140766922  english  This game destroys lives and breaks families. ...
# 52096  140766772  english  this is such a fun you need to try it out the ...
# 52097  140766435  english                                                 gg
# 52098  140766317  english  De los mejores juegos del mundo... Mas que nad...
#
#                    created  voted_up  votes_up  comment_count  steam_purchase  \
# 52094  2023-06-27 04:16:29      True         0              0            True
# 52095  2023-06-27 04:01:43     False         0              0            True
# 52096  2023-06-27 03:57:22      True         0              0            True
# 52097  2023-06-27 03:48:20      True         0              0            True
# 52098  2023-06-27 03:44:44      True         0              0            True
#
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 52099 entries, 0 to 52098
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              52099 non-null  int64
#  1   language                        52099 non-null  object
#  2   review                          51803 non-null  object
#  3   created                         52099 non-null  object
#  4   voted_up                        52099 non-null  bool
#  5   votes_up                        52099 non-null  int64
#  6   comment_count                   52099 non-null  int64
#  7   steam_purchase                  52099 non-null  bool
#  8   recieved_for_free               52099 non-null  bool
#  9   written_during_early_access     52099 non-null  bool
#  10  author_num_games_owned          52099 non-null  int64
#  11  author_num_reviews              52099 non-null  int64
# ...

# %% [markdown]
# **Clasificacion de datos**

# %%
df_sorted = df.sort_values(by='id', ascending=True)
print(df_sorted[['id','language','review', 'created','voted_up','votes_up','comment_count','steam_purchase','recieved_for_free','written_during_early_access','author_num_games_owned','author_num_reviews','author_playtime_forever','author_playtime_last_two_weeks','author_playtime_at_review','author_last_played']])
df
# Out:
#               id language                                             review  \
# 52098  140766317  english  De los mejores juegos del mundo... Mas que nad...
# 52097  140766435  english                                                 gg
# 52096  140766772  english  this is such a fun you need to try it out the ...
# 52095  140766922  english  This game destroys lives and breaks families. ...
# 52094  140767442  english                                         great game
# ...          ...      ...                                                ...
# 4      157335380  english                                                sed
# 3      157336468  english                                               best
# 2      157337210  english                                         great game
# 1      157337371  english         modders make it better and free everything
# 0      157337410  english  Games good, But Rockstar Your a BILLION DOLLAR...
#
# ...

# %% [markdown]
# **Clasificacion en cualitatico y cuantitativos**

# %% [markdown]
# **Cualitativo**

# %%
cualitativos = df[['language', 'review', 'created','voted_up','steam_purchase','recieved_for_free','written_during_early_access','author_last_played']]
print(cualitativos)
# Out:
#       language                                             review  \
# 0      english  Games good, But Rockstar Your a BILLION DOLLAR...
# 1      english         modders make it better and free everything
# 2      english                                         great game
# 3      english                                               best
# 4      english                                                sed
# ...        ...                                                ...
# 52094  english                                         great game
# 52095  english  This game destroys lives and breaks families. ...
# 52096  english  this is such a fun you need to try it out the ...
# 52097  english                                                 gg
# 52098  english  De los mejores juegos del mundo... Mas que nad...
#
#                    created  voted_up  steam_purchase  recieved_for_free  \
# 0      2024-02-01 16:00:22      True            True              False
# ...

# %% [markdown]
# **Cuantitativo**

# %%
cuantitativos = df[['id', 'votes_up','comment_count','author_num_games_owned','author_num_reviews','author_playtime_forever','author_playtime_last_two_weeks','author_playtime_at_review']]
print(cuantitativos)
# Out:
#               id  votes_up  comment_count  author_num_games_owned  \
# 0      157337410         0              0                       0
# 1      157337371         0              0                       0
# 2      157337210         0              0                       0
# 3      157336468         0              0                      34
# 4      157335380         0              0                      11
# ...          ...       ...            ...                     ...
# 52094  140767442         0              0                       0
# 52095  140766922         0              0                       0
# 52096  140766772         0              0                       0
# 52097  140766435         0              0                       0
# 52098  140766317         0              0                      15
#
#        author_num_reviews  author_playtime_forever  \
# 0                       9                     9105
# 1                       1                     2530
# ...

# %% [markdown]
# **Manejo de outliers**

# %%
import matplotlib.pyplot as plt
plt.scatter(df.index, df['author_playtime_last_two_weeks'])
plt.xlabel('Index')
plt.ylabel('Steam Purchase')
plt.title('Scatter Plot of Steam Purchase')
plt.show()

# %%
filtered_df = df[(df['author_playtime_last_two_weeks'] > 7500) & (df['author_playtime_last_two_weeks'] <= 10000)]
outliers = pd.DataFrame(filtered_df)

outliers
# Out:
#               id language                                             review  \
# 129    157292600  english  The game forces you to need other players to r...
# 160    157283696  english                               absolutly worth it\n
# 188    157270106  english  GTA Online is such a pain experience, I never ...
# 480    157172435  english  It is unfortunate that an advanced cheat provi...
# 886    157031395  english                                              10/10
# ...          ...      ...                                                ...
# 43480  142820609  english                                 liberty.mp/discord
# 45452  142381625  english                                               nice
# 45477  142376515  english                                              yes\n
# 45681  142312879  english     yooooooooooooooooooooooooooooo this game tasty
# 45782  142291258  english                                               good
#
# ...

# %% [markdown]
# **Valores null**

# %%
null_values = df.isnull()
print(null_values)
# Out:
#           id  language  review  created  voted_up  votes_up  comment_count  \
# 0      False     False   False    False     False     False          False
# 1      False     False   False    False     False     False          False
# 2      False     False   False    False     False     False          False
# 3      False     False   False    False     False     False          False
# 4      False     False   False    False     False     False          False
# ...      ...       ...     ...      ...       ...       ...            ...
# 52094  False     False   False    False     False     False          False
# 52095  False     False   False    False     False     False          False
# 52096  False     False   False    False     False     False          False
# 52097  False     False   False    False     False     False          False
# 52098  False     False   False    False     False     False          False
#
# ...

# %% [markdown]
# **Valores no null**

# %%
not_null_values = df.notnull()
print(not_null_values)
# Out:
#          id  language  review  created  voted_up  votes_up  comment_count  \
# 0      True      True    True     True      True      True           True
# 1      True      True    True     True      True      True           True
# 2      True      True    True     True      True      True           True
# 3      True      True    True     True      True      True           True
# 4      True      True    True     True      True      True           True
# ...     ...       ...     ...      ...       ...       ...            ...
# 52094  True      True    True     True      True      True           True
# 52095  True      True    True     True      True      True           True
# 52096  True      True    True     True      True      True           True
# 52097  True      True    True     True      True      True           True
# 52098  True      True    True     True      True      True           True
#
#        steam_purchase  recieved_for_free  written_during_early_access  \
# ...

# %%
df.dropna(inplace=True)
df
# Out:
#               id language                                             review  \
# 0      157337410  english  Games good, But Rockstar Your a BILLION DOLLAR...
# 1      157337371  english         modders make it better and free everything
# 2      157337210  english                                         great game
# 3      157336468  english                                               best
# 4      157335380  english                                                sed
# ...          ...      ...                                                ...
# 52094  140767442  english                                         great game
# 52095  140766922  english  This game destroys lives and breaks families. ...
# 52096  140766772  english  this is such a fun you need to try it out the ...
# 52097  140766435  english                                                 gg
# 52098  140766317  english  De los mejores juegos del mundo... Mas que nad...
#
# ...

# %% [markdown]
# **Correlaciones entre Variables**

# %%
correlation_matrix = df.corr()
print(correlation_matrix)
# Out:
#                                       id  voted_up  votes_up  comment_count  \
# id                              1.000000  0.031641  0.000812      -0.008744
# voted_up                        0.031641  1.000000 -0.007255      -0.033487
# votes_up                        0.000812 -0.007255  1.000000       0.247578
# comment_count                  -0.008744 -0.033487  0.247578       1.000000
# steam_purchase                  0.004323  0.029573 -0.000043      -0.007712
# recieved_for_free              -0.007413  0.037711 -0.005641       0.015902
# written_during_early_access          NaN       NaN       NaN            NaN
# author_num_games_owned          0.003836 -0.079389  0.032445       0.017851
# author_num_reviews             -0.012672 -0.094172  0.028370       0.033161
# author_playtime_forever        -0.051335 -0.060020  0.010955       0.044847
# author_playtime_last_two_weeks  0.190655  0.020297 -0.002363       0.009389
# ...

# %%
df.to_csv('LABORATORIO_EDA_UNO.csv', index=False)
